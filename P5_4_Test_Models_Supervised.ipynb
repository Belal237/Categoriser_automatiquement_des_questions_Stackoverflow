# %% [markdown]
# # <center> Projet 5 : Catégorisez automatiquement des questions sur Stack Overflow

# %% [markdown]
# Dans cette partie nous allons tester les différents models, supervisés

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import Python libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import seaborn as sns
import re
import nltk
import pickle
import time
import spacy
import logging
import gensim
import gensim.corpora as corpora
import multiprocessing
# %matplotlib inline
logging.disable(logging.WARNING) # disable WARNING, INFO and DEBUG logging everywhere
import warnings
warnings.filterwarnings("ignore")

# %%
from tqdm import tqdm 
from ast import literal_eval
from bs4 import BeautifulSoup
from sklearn import cluster, metrics
from sklearn import manifold, decomposition
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import EnglishStemmer
from wordcloud import WordCloud
from spacy import displacy

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import f1_score, jaccard_score, roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

# %%
X_train_tfidf = joblib.load('../Variables/X_train_tfidf.joblib')
X_test_tfidf = joblib.load('../Variables/X_test_tfidf.joblib')

# %%
Xw2v_train = joblib.load('../Variables/Xw2v_train.joblib')
Xw2v_test = joblib.load('../Variables/Xw2v_test.joblib')

# %%
X_train_bert_hf = joblib.load('../Variables/X_train_bert_hf.joblib')
X_test_bert_hf = joblib.load('../Variables/X_test_bert_hf.joblib')

# %%
X_train_use = joblib.load('../Variables/X_train_use.joblib')
X_test_use = joblib.load('../Variables/X_test_use.joblib')

# %%
X_train = joblib.load('../Variables/X_train.joblib')
X_test = joblib.load('../Variables/X_test.joblib')

# %%
y_train = joblib.load('../Variables/y_train.joblib')
y_test = joblib.load('../Variables/y_test.joblib')

# %%
multilabel = joblib.load('../Models/multilabel.joblib')

# %%
def modeltrainer(Xtrain, Xtest, ytrain, ytest, model):
    """
    Cette fonction va nous permettre d'entrainer les modèles puis génerer les feteares importances de chaque model. 
    """
    print("=="*45)
    print("Modele utilise : {}".format(model))
    score =  {}
    time1 = time.time()
    model.fit(Xtrain, ytrain)
    y_pred = model.predict(Xtest)
    time2 = time.time()
    print("Temps d'entrainement : {:.2f}s".format(time2 - time1))
    # Evaluate model
    print("Evaluation du modele ... ")    
    f1 = f1_score(ytest, y_pred, average='micro')
    jaccard = jaccard_score(ytest, y_pred, average='micro')
    roc_auc =roc_auc_score(ytest, y_pred, average='micro')
    time3 = time.time()
    # Dictionnary of score
    score['f1_score'] = f1
    score['jaccard_score'] = jaccard
    score['ROC_Auc_score'] = roc_auc 
    print("Temps d'evaluation : {:.2f}s".format(time3 - time2))
    times = time3 - time1

    return y_pred, score, model, times

# %%
def predict_tags(multilabel, y_pred):
    pred_tags = multilabel.inverse_predict(y_pred)
    return pred_tags

# %% [markdown]
# ## TFIDF

# %% [markdown]
# ### Logistic Regression

# %%
log_reg_model = OneVsRestClassifier(estimator=LogisticRegression(penalty='l1',
                                                                 solver='saga',
                                                                 C=100,
                                                                 n_jobs=-1), 
                                    n_jobs=-1)

# %%
ytfidf_pred_lr, score_tfidf_lr, model_tfidf_lr, time_tfidf_lr = modeltrainer(
    X_train_tfidf, X_test_tfidf, y_train, y_test, log_reg_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=LogisticRegression(C=100, n_jobs=-1, penalty='l1',
#                                                  solver='saga'),
#                     n_jobs=-1)
# Temps d'entrainement : 1364.39s
# Evaluation du modele ...
# Temps d'evaluation : 2.16s

# %%
multilabel.inverse_transform(ytfidf_pred_lr)
# Out:
# [(),
#  ('c++',),
#  (),
#  (),
#  (),
#  (),
#  ('post',),
#  (),
#  (),
#  ('c#',),
#  (),
#  (),
#  ('python',),
#  (),
#  ('ios', 'ios7', 'objective-c', 'swift', 'uikit'),
#  ('javascript',),
#  (),
#  ('collections',),
#  ('css',),
#  ('json', 'post'),
#  (),
#  (),
#  ('javascript',),
#  ('asp.net-mvc',),
#  (),
#  ('android',),
#  ('arrays', 'java'),
#  ('javascript',),
#  (),
#  (),
#  ('unit-testing',),
#  ('sql',),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  ('java', 'spring', 'spring-boot', 'spring-mvc'),
#  ('git',),
#  ('json', 'serialization'),
#  (),
#  (),
#  (),
#  ('sql', 'sql-server'),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('ios', 'iphone', 'objective-c'),
#  (),
#  ('arrays', 'javascript', 'jquery', 'object'),
#  (),
#  (),
#  ('android',),
#  (),
#  (),
#  ('performance',),
#  (),
#  (),
#  ('javascript', 'jquery'),
#  ('java',),
#  ('assembly', 'c', 'c++'),
#  (),
#  ('c#', 'visual-studio'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('.net-core', 'c#'),
#  (),
#  ('linux',),
#  (),
#  (),
#  ('date',),
#  (),
#  ('java', 'multithreading'),
#  ('php',),
#  (),
#  ('java',),
#  ('java', 'performance'),
#  (),
#  ('xml',),
#  ('javascript',),
#  ('java',),
#  (),
#  ('deployment', 'ruby-on-rails'),
#  ('android-layout', 'ios', 'objective-c', 'uitableview'),
#  ('python',),
#  (),
#  ('colors', 'image'),
#  ('android',),
#  ('python',),
#  (),
#  (),
#  (),
#  ('java',),
#  ('php',),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  ('linux',),
#  (),
#  (),
#  ('python',),
#  ('arrays',),
#  ('jquery',),
#  (),
#  ('ios',),
#  (),
#  ('performance',),
#  ('ios', 'laravel'),
#  ('python',),
#  ('image-processing', 'python'),
#  (),
#  ('javascript',),
#  ('c#',),
#  ('.net-core', 'asp.net-core', 'c#'),
#  ('jquery',),
#  ('linux',),
#  (),
#  ('datetime', 'sql', 'sql-server', 'tsql'),
#  (),
#  ('.net', 'c#', 'winforms'),
#  ('javascript', 'reactjs', 'vue.js'),
#  ('selenium', 'selenium-webdriver'),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  ('generics',),
#  ('ios',),
#  (),
#  (),
#  ('list',),
#  ('python',),
#  (),
#  ('inheritance', 'java'),
#  ('json',),
#  (),
#  ('c++', 'class'),
#  (),
#  ('html', 'javascript'),
#  ('ios',),
#  (),
#  (),
#  (),
#  ('java',),
#  ('java', 'xml'),
#  ('android',),
#  ('multithreading',),
#  ('python',),
#  ('database', 'mysql', 'php'),
#  ('asp.net', 'c#', 'visual-studio-2012'),
#  ('reactjs', 'vue.js'),
#  ('python',),
#  ('ios',),
#  (),
#  ('javascript', 'jquery'),
#  (),
#  (),
#  ('android', 'android-studio'),
#  ('curl', 'php'),
#  (),
#  ('android',),
#  (),
#  ('javascript', 'jquery'),
#  (),
#  ('objective-c',),
#  ('css', 'jquery'),
#  ('python',),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('asp.net-core', 'c#'),
#  (),
#  (),
#  (),
#  ('iis',),
#  (),
#  ('c++',),
#  ('dataframe', 'pandas', 'python'),
#  ('jquery',),
#  ('asp.net-mvc', 'c#', 'entity-framework'),
#  (),
#  (),
#  ('algorithm', 'c', 'c++', 'floating-point', 'math'),
#  ('asp.net',),
#  (),
#  (),
#  ('css', 'html', 'javascript', 'jquery', 'twitter-bootstrap'),
#  ('uiview',),
#  ('api', 'php', 'rest'),
#  ('linux',),
#  (),
#  (),
#  ('java', 'spring'),
#  ('css', 'html', 'javascript'),
#  ('java', 'logging', 'spring', 'spring-boot'),
#  ('cors', 'html'),
#  ('java',),
#  (),
#  (),
#  (),
#  ('python',),
#  ('c#',),
#  ('c', 'c++', 'multithreading'),
#  ('css',),
#  ('c++',),
#  (),
#  (),
#  ('javascript', 'jquery'),
#  (),
#  ('python',),
#  ('inheritance',),
#  (),
#  ('java',),
#  ('entity-framework',),
#  (),
#  (),
#  (),
#  ('image', 'iphone'),
#  ('winapi', 'windows'),
#  (),
#  ('arrays', 'javascript'),
#  (),
#  ('string',),
#  ('asp.net-mvc', 'asp.net-web-api', 'c#', 'cors'),
#  ('dataframe', 'numpy', 'pandas', 'python'),
#  ('list',),
#  ('path',),
#  ('ajax', 'javascript', 'jquery'),
#  (),
#  (),
#  ('arrays', 'java', 'object'),
#  (),
#  (),
#  ('class',),
#  ('css',),
#  ('css',),
#  (),
#  ('database-design', 'mysql', 'sql', 'sql-server', 'tsql'),
#  ('python',),
#  ('indexing',),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  ('java', 'maven'),
#  (),
#  ('asp.net-mvc', 'asp.net-mvc-3'),
#  ('jquery',),
#  (),
#  ('list',),
#  ('sql', 'sql-server'),
#  ('python',),
#  (),
#  ('javascript',),
#  ('css',),
#  ('class', 'java'),
#  (),
#  ('json',),
#  ('css', 'dom', 'html', 'javascript'),
#  ('php',),
#  ('hibernate', 'java', 'jpa', 'spring', 'spring-boot', 'spring-mvc'),
#  (),
#  ('php',),
#  ('python', 'python-3.x'),
#  (),
#  (),
#  (),
#  (),
#  ('sql', 'sql-server', 'tsql'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('indexing', 'java'),
#  ('entity-framework',),
#  ('iphone',),
#  ('json',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  ('sockets',),
#  ('visual-studio',),
#  (),
#  (),
#  ('arrays', 'python'),
#  ('ios', 'macos', 'xcode'),
#  (),
#  (),
#  ('selenium',),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  ('javascript', 'jquery'),
#  (),
#  ('android', 'xml'),
#  (),
#  ('url',),
#  ('arrays',),
#  ('asp.net-core',),
#  ('batch-file', 'windows'),
#  ('python',),
#  ('javascript', 'jquery'),
#  (),
#  (),
#  (),
#  ('android',),
#  ('html', 'javascript'),
#  ('jquery', 'json', 'php'),
#  ('class', 'java'),
#  (),
#  ('java', 'maven'),
#  (),
#  (),
#  ('php',),
#  (),
#  ('ios',),
#  ('unit-testing',),
#  ('java',),
#  (),
#  (),
#  ('objective-c', 'uitableview'),
#  (),
#  ('java', 'json'),
#  (),
#  (),
#  ('php',),
#  (),
#  ('sql', 'sql-server'),
#  ('python',),
#  ('c++', 'visual-c++'),
#  ('.net-core', 'asp.net-web-api', 'c#'),
#  (),
#  ('java', 'spring'),
#  ('java',),
#  ('list',),
#  (),
#  (),
#  (),
#  ('numpy', 'python'),
#  (),
#  ('linq',),
#  (),
#  (),
#  ('assembly', 'c', 'c++'),
#  (),
#  ('java',),
#  ('sql', 'sql-server', 'tsql'),
#  (),
#  ('javascript',),
#  ('javascript',),
#  ('android', 'android-gradle-plugin', 'android-studio', 'gradle', 'java'),
#  ('javascript', 'php', 'xml'),
#  (),
#  ('java',),
#  ('browser', 'javascript', 'npm'),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  ('ruby-on-rails',),
#  (),
#  ('php',),
#  ('python',),
#  ('arrays',),
#  ('android',),
#  (),
#  ('c', 'c++', 'linux'),
#  ('android',),
#  (),
#  ('functional-programming',),
#  ('selenium',),
#  (),
#  (),
#  (),
#  (),
#  ('json',),
#  ('java', 'spring'),
#  ('android',),
#  ('php',),
#  ('exception',),
#  ('java',),
#  (),
#  (),
#  (),
#  (),
#  ('colors',),
#  (),
#  (),
#  ('java',),
#  ('c#', 'linq'),
#  (),
#  ('architecture', 'python'),
#  ('ios', 'iphone', 'objective-c'),
#  (),
#  ('sql-server',),
#  (),
#  ('button',),
#  (),
#  ('c++',),
#  ('python',),
#  (),
#  ('iphone',),
#  (),
#  (),
#  ('mysql', 'php'),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  ('java', 'spring', 'spring-boot', 'spring-mvc'),
#  ('data-structures', 'java'),
#  ('android', 'android-layout'),
#  ('bash', 'linux', 'shell'),
#  ('python', 'text'),
#  ('c', 'c++'),
#  (),
#  (),
#  ('browser',),
#  ('database-design', 'sql', 'sql-server', 'sql-server-2008'),
#  ('javascript',),
#  ('python',),
#  ('c#',),
#  ('android', 'ios'),
#  ('css', 'html', 'input'),
#  ('file-upload', 'php'),
#  (),
#  ('java',),
#  (),
#  ('javascript', 'reactjs', 'twitter-bootstrap'),
#  ('list',),
#  ('object', 'python'),
#  ('xml',),
#  ('python',),
#  (),
#  ('javascript', 'jquery'),
#  (),
#  ('android', 'android-layout'),
#  ('colors',),
#  (),
#  ('datetime', 'oracle', 'sql', 'sql-server', 'sql-server-2005'),
#  ('numpy', 'python'),
#  (),
#  ('events', 'javascript'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('html', 'selenium', 'selenium-webdriver'),
#  ('xml',),
#  (),
#  ('ios', 'iphone'),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('asp.net', 'asp.net-mvc', 'asp.net-mvc-4', 'asp.net-web-api', 'c#'),
#  (),
#  (),
#  (),
#  (),
#  ('dependency-injection',),
#  (),
#  ('php',),
#  (),
#  (),
#  ('async-await', 'asynchronous', 'c#', 'java', 'multithreading'),
#  (),
#  (),
#  ('exception', 'java'),
#  (),
#  ('ruby', 'ruby-on-rails'),
#  (),
#  (),
#  ('css', 'html', 'javascript', 'jquery'),
#  (),
#  ('asp.net', 'asp.net-web-api', 'c#'),
#  ('json', 'rest', 'wcf', 'web-services'),
#  ('jquery',),
#  ('apache-spark', 'pandas'),
#  (),
#  ('arrays', 'javascript', 'json'),
#  ('java', 'javascript'),
#  (),
#  ('unit-testing',),
#  (),
#  ('python', 'python-2.7', 'python-3.x'),
#  ('php',),
#  (),
#  (),
#  (),
#  (),
#  ('json',),
#  (),
#  (),
#  (),
#  (),
#  ('javascript', 'jquery'),
#  ('java', 'json', 'rest'),
#  (),
#  (),
#  ('entity-framework',),
#  ('c#',),
#  ('gradle',),
#  (),
#  (),
#  (),
#  ('colors',),
#  ('dictionary', 'python'),
#  ('angular', 'vue.js', 'webpack'),
#  (),
#  ('android', 'opencv'),
#  ('sql',),
#  (),
#  ('null',),
#  ('image', 'php'),
#  (),
#  ('linux',),
#  ('arrays', 'python'),
#  ('java',),
#  (),
#  (),
#  ('file-upload',),
#  (),
#  ('database',
#   'entity-framework',
#   'mysql',
#   'performance',
#   'postgresql',
#   'sql',
#   'sql-server'),
#  (),
#  ('c++',),
#  ('java',),
#  ('datetime',),
#  ('api',),
#  (),
#  ('.net', 'c#'),
#  (),
#  ('html', 'javascript'),
#  ('python',),
#  ('asp.net-mvc', 'c#'),
#  (),
#  (),
#  (),
#  ('performance',),
#  (),
#  ('html',),
#  (),
#  (),
#  (),
#  ('java',),
#  ('android',),
#  ('image-processing', 'opencv'),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  ('postgresql', 'sql'),
#  ('maven',),
#  (),
#  (),
#  ('ajax', 'javascript', 'jquery'),
#  ('ios',),
#  ('rest',),
#  ('string',),
#  (),
#  ('firebase',),
#  ('unit-testing',),
#  (),
#  (),
#  ('jpa', 'spring', 'sql'),
#  ('entity-framework', 'sql-server'),
#  (),
#  ('json',),
#  ('.net', 'c#', 'entity-framework'),
#  (),
#  ('android-studio', 'visual-studio'),
#  ('list', 'python'),
#  ('arrays',),
#  (),
#  ('sql-server',),
#  ('asp.net-mvc',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  ('api', 'google-maps'),
#  ('java', 'spring'),
#  ('c#',),
#  (),
#  (),
#  ('css', 'jquery'),
#  (),
#  ('android', 'java'),
#  ('c++', 'multithreading'),
#  ('angular', 'javascript', 'reactjs', 'typescript', 'webpack'),
#  ('python',),
#  ('dictionary', 'python'),
#  (),
#  (),
#  (),
#  ('shell',),
#  ('python',),
#  (),
#  ('http', 'php'),
#  (),
#  (),
#  ('windows',),
#  ('pip',),
#  (),
#  (),
#  ('ios',),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  ('post',),
#  (),
#  ('algorithm', 'data-structures', 'list', 'python'),
#  (),
#  (),
#  (),
#  ('docker',),
#  ('android',),
#  ('ios', 'iphone', 'xcode'),
#  ('reactjs',),
#  (),
#  ('java',),
#  (),
#  ('c++', 'compiler-construction'),
#  (),
#  ('bash',),
#  ('c#', 'visual-studio-2012'),
#  ('css', 'html', 'input'),
#  ('c', 'c++', 'gcc', 'linux'),
#  (),
#  ('asp.net-mvc', 'c#', 'entity-framework'),
#  ('python', 'python-2.7', 'python-3.x'),
#  (),
#  ('sql',),
#  ('dom', 'xml'),
#  ('c',),
#  (),
#  ('python',),
#  (),
#  ('cors',),
#  ('java', 'json'),
#  (),
#  (),
#  ('python',),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('string',),
#  ('java',),
#  ('reactjs',),
#  ('ajax', 'asp.net-mvc-4', 'javascript', 'jquery'),
#  ('node.js',),
#  ('.net', 'c#'),
#  ('ios',),
#  (),
#  ('exception',),
#  ('c#',),
#  ('javascript', 'jquery'),
#  (),
#  ('ios',),
#  ('javascript', 'jquery'),
#  (),
#  (),
#  (),
#  (),
#  ('amazon-web-services',),
#  (),
#  ('tensorflow',),
#  ('arrays', 'numpy'),
#  ('sql', 'sql-server'),
#  ('encryption', 'php'),
#  ('dom', 'html', 'javascript', 'jquery'),
#  ('windows',),
#  ('sql',),
#  ('java',),
#  (),
#  ('class', 'css'),
#  (),
#  ('ios', 'iphone', 'objective-c'),
#  ('android',),
#  ('python',),
#  (),
#  ('java',),
#  ('asp.net', 'asp.net-mvc', 'c#'),
#  ('javascript',),
#  ('python', 'ssh'),
#  (),
#  ('colors',),
#  ('ios',),
#  ('ios', 'ios7', 'iphone', 'objective-c', 'swift', 'uitableview', 'xcode'),
#  (),
#  (),
#  (),
#  ('asp.net-mvc', 'c#', 'entity-framework'),
#  ('android',),
#  ('sockets',),
#  ('windows',),
#  ('arrays',),
#  (),
#  ('android',),
#  ('php',),
#  (),
#  ('ios', 'objective-c'),
#  ('text',),
#  (),
#  (),
#  (),
#  (),
#  ('ios', 'objective-c', 'uiviewcontroller'),
#  ('javascript', 'jquery'),
#  (),
#  ('multithreading',),
#  (),
#  (),
#  ('ios',),
#  (),
#  (),
#  ('javascript', 'reactjs'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('mocking', 'testing', 'unit-testing'),
#  (),
#  ('css', 'html'),
#  ('sql',),
#  (),
#  ('linux',),
#  ('performance', 'sql'),
#  ('colors', 'javascript'),
#  ('types',),
#  ('java',),
#  (),
#  (),
#  ('arrays', 'python'),
#  (),
#  ('arrays', 'numpy'),
#  ('python',),
#  (),
#  (),
#  (),
#  ('database', 'mysql', 'sql'),
#  ('c', 'c++'),
#  ('java', 'spring'),
#  ('javascript', 'jquery'),
#  ('jquery', 'json'),
#  (),
#  ('java', 'spring', 'spring-boot', 'spring-mvc', 'tomcat'),
#  ('console',),
#  (),
#  ('python',),
#  ('c#',),
#  ('jquery', 'time'),
#  ('java',),
#  (),
#  ('multithreading',),
#  ('colors',),
#  (),
#  ('android',
#   'android-gradle-plugin',
#   'android-studio',
#   'gradle',
#   'intellij-idea'),
#  ('arrays', 'php'),
#  (),
#  ('python',),
#  ('ajax', 'jquery', 'json', 'php'),
#  ('python',),
#  (),
#  ('android',),
#  (),
#  ('concurrency', 'java'),
#  ('date', 'datetime', 'sql', 'sql-server'),
#  ('json', 'python'),
#  ('jquery',),
#  ('date',),
#  ('java',),
#  ('ios', 'uiscrollview'),
#  (),
#  ('ios',),
#  ('ios',),
#  (),
#  (),
#  (),
#  (),
#  ('floating-point',),
#  ('url',),
#  (),
#  (),
#  ('pip', 'python'),
#  ('python',),
#  ('android',),
#  (),
#  ('python',),
#  ('javascript',),
#  ('python',),
#  ('css', 'html', 'javascript', 'jquery'),
#  ('ruby', 'ruby-on-rails', 'ruby-on-rails-3'),
#  (),
#  ('.net', 'c#', 'entity-framework'),
#  ('php',),
#  ('exception',),
#  ('python',),
#  ('uiscrollview',),
#  ('java',),
#  (),
#  (),
#  (),
#  ('ios', 'iphone', 'objective-c', 'xcode'),
#  ('ios', 'ios7', 'objective-c', 'uiviewcontroller'),
#  ('unit-testing',),
#  ('cors', 'wcf', 'web-services'),
#  (),
#  (),
#  ('database', 'mysql', 'postgresql', 'sql', 'sql-server'),
#  (),
#  (),
#  ('ios', 'iphone'),
#  ('html',),
#  ('string',),
#  ('css', 'jquery'),
#  ('php',),
#  ('node.js',),
#  (),
#  ('linux',),
#  ('java',),
#  ('javascript', 'jquery'),
#  ('gradle',),
#  (),
#  ('events', 'html', 'javascript', 'jquery'),
#  ('python',),
#  (),
#  ('javascript',),
#  (),
#  ('javascript',),
#  (),
#  ('c#',),
#  ('asp.net', 'asp.net-web-api'),
#  (),
#  (),
#  (),
#  (),
#  ('firebase',),
#  ('python',),
#  ('c#',),
#  ('hibernate', 'mysql'),
#  (),
#  (),
#  (),
#  ('java',),
#  ('c#',),
#  ('javascript', 'jquery', 'jquery-ui'),
#  (),
#  (),
#  (),
#  ('php',),
#  ('entity-framework',),
#  ('python',),
#  (),
#  ('dataframe', 'pandas'),
#  (),
#  ('android',),
#  (),
#  ('ios',),
#  (),
#  ('php',),
#  (),
#  (),
#  (),
#  ('css', 'html'),
#  ('html', 'javascript', 'jquery'),
#  ('date', 'datetime', 'java'),
#  ('android',),
#  ('android', 'android-gradle-plugin', 'android-studio', 'gradle'),
#  ('html', 'javascript', 'twitter-bootstrap'),
#  ('functional-programming', 'haskell'),
#  ('android', 'google-maps'),
#  (),
#  (),
#  (),
#  ('unit-testing',),
#  ('android',),
#  ('wpf',),
#  ('batch-file', 'linux', 'windows'),
#  ('iphone',),
#  (),
#  ('android',),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  ('google-maps',),
#  ('language-agnostic',),
#  (),
#  ('java',),
#  (),
#  ('python',),
#  ('android', 'ios'),
#  ('c++', 'multithreading'),
#  ('c++',),
#  (),
#  ('json', 'python'),
#  ('ios',),
#  (),
#  ('console',),
#  ('javascript', 'jquery'),
#  (),
#  ('bash', 'windows'),
#  ('c#', 'list'),
#  ('javascript', 'jquery'),
#  (),
#  ('java',),
#  (),
#  (),
#  ('android',),
#  ('entity-framework',),
#  (),
#  ('json', 'python'),
#  ('c++',),
#  ('html',),
#  ('arrays',),
#  ('java', 'json'),
#  (),
#  (),
#  ('image', 'javascript'),
#  (),
#  (),
#  (),
#  ('c', 'c++', 'floating-point', 'optimization'),
#  ('asp.net-mvc',),
#  (),
#  ('css',),
#  (),
#  (),
#  ('php',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('visual-studio',),
#  (),
#  ('google-maps', 'javascript'),
#  ('android-studio', 'gradle'),
#  ('button',),
#  (),
#  ('memory',),
#  ('c++', 'class'),
#  ('html',),
#  (),
#  (),
#  ('json',),
#  ('java',),
#  ('python',),
#  (),
#  ...]

# %%
score_tfidf_lr
# Out:
# {'f1_score': 0.32651113733959464,
#  'jaccard_score': 0.19510804321728692,
#  'ROC_Auc_score': 0.6097414936715185}

# %%
joblib.dump(ytfidf_pred_lr, open("../Variables/ytfidf_pred_lr.joblib", 'wb'), compress=True)
joblib.dump(score_tfidf_lr, open("../Scores/score_tfidf_lr.joblib", 'wb'), compress=True)
joblib.dump(model_tfidf_lr, open("../Models/model_tfidf_lr.joblib", 'wb'), compress=True)

# %% [markdown]
# ### Random Forest

# %%
rfc_model = OneVsRestClassifier(estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1)

# %%
ytfidf_pred_rf, score_tfidf_rf, model_tfidf_rf, time_tfidf_rf = modeltrainer(
    X_train_tfidf, X_test_tfidf, y_train, y_test, rfc_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1)
# Temps d'entrainement : 1560.35s
# Evaluation du modele ...
# Temps d'evaluation : 2.12s

# %%
score_tfidf_rf
# Out:
# {'f1_score': 0.261217813125758,
#  'jaccard_score': 0.15023032505028222,
#  'ROC_Auc_score': 0.5784086660625621}

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ### Logistic regression

# %%
log_reg_model = OneVsRestClassifier(estimator=LogisticRegression(penalty='l1',
                                                                 solver='saga',
                                                                 C=100,
                                                                 n_jobs=-1), 
                                    n_jobs=-1)

# %%
yw2v_pred_lr, score_w2v_lr, model_w2v_lr, time_w2v_lr = modeltrainer(
    Xw2v_train, Xw2v_test, y_train, y_test, log_reg_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=LogisticRegression(C=100, n_jobs=-1, penalty='l1',
#                                                  solver='saga'),
#                     n_jobs=-1)
# Temps d'entrainement : 1447.18s
# Evaluation du modele ...
# Temps d'evaluation : 1.06s

# %%
score_w2v_lr
# Out:
# {'f1_score': 0.4104587833471799,
#  'jaccard_score': 0.25822468712796537,
#  'ROC_Auc_score': 0.6501723633603349}

# %%
joblib.dump(yw2v_pred_lr, open('../Variables/yw2v_pred_lr.joblib', 'wb'), compress=True)
joblib.dump(score_w2v_lr, open("../Scores/score_w2v_lr.joblib", 'wb'), compress=True)
joblib.dump(model_w2v_lr, open("../Models/model_w2v_lr.joblib", 'wb'), compress=True)

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc_model = OneVsRestClassifier(estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1)

# %%
yw2v_pred_rf, score_w2v_rf, model_w2v_lr, time_w2v_rf = modeltrainer(
    Xw2v_train, Xw2v_test, y_train, y_test, rfc_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1)
# Temps d'entrainement : 3955.50s
# Evaluation du modele ...
# Temps d'evaluation : 2.17s

# %%
score_w2v_rf
# Out:
# {'f1_score': 0.14006332650400447,
#  'jaccard_score': 0.07530542759863809,
#  'ROC_Auc_score': 0.538223873400425}

# %%
multilabel.inverse_transform(yw2v_pred_rf)
# Out:
# [(),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('ios',),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c', 'c++'),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  ('java',),
#  ('android',),
#  ('java', 'spring'),
#  (),
#  ('json',),
#  (),
#  (),
#  (),
#  (),
#  ('java',),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  ('c',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c#',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('mysql', 'php'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  ('ios',),
#  ('python',),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c++',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c#',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('reactjs',),
#  (),
#  (),
#  (),
#  ('css',),
#  (),
#  (),
#  ('c++',),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('html', 'javascript'),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  ('multithreading',),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c++',),
#  (),
#  ('css', 'javascript'),
#  (),
#  (),
#  (),
#  ('c++',),
#  (),
#  (),
#  (),
#  ('html', 'javascript', 'jquery'),
#  ('ios', 'iphone', 'objective-c'),
#  (),
#  (),
#  (),
#  (),
#  ('java',),
#  ('javascript',),
#  (),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c#',),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('node.js', 'npm'),
#  ('javascript', 'jquery'),
#  ('html',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('css', 'html'),
#  (),
#  (),
#  ('sql',),
#  ('pip', 'python'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sql',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  ('java', 'spring'),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  ('sql',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('json',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('arrays',),
#  ('xcode',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  ('javascript',),
#  (),
#  (),
#  (),
#  ('android',),
#  ('html',),
#  (),
#  ('java',),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  ('java',),
#  (),
#  ('ios',),
#  (),
#  ('git',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sql',),
#  ('java',),
#  (),
#  (),
#  ('html',),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  ('java', 'spring'),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  (),
#  (),
#  ('wpf',),
#  (),
#  ('c++',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  ('java', 'maven', 'spring', 'spring-boot'),
#  ('java',),
#  ('android',),
#  ('linux',),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  ('css', 'html'),
#  (),
#  (),
#  ('java',),
#  (),
#  ('html', 'javascript', 'jquery', 'twitter-bootstrap'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  ('javascript',),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('php',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  ('ruby', 'ruby-on-rails'),
#  (),
#  (),
#  ('html',),
#  (),
#  ('c#',),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c#',),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  ('webpack',),
#  (),
#  (),
#  (),
#  (),
#  ('c++',),
#  (),
#  (),
#  ('linux',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c++',),
#  (),
#  (),
#  (),
#  ('multithreading',),
#  (),
#  (),
#  ('html',),
#  ('python',),
#  (),
#  (),
#  (),
#  ('sql',),
#  (),
#  (),
#  (),
#  (),
#  ('ios', 'objective-c'),
#  (),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('visual-studio',),
#  (),
#  ('arrays',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('multithreading',),
#  ('javascript', 'reactjs'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('functional-programming',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  ('ios', 'iphone', 'uitableview'),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('xcode',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('css', 'html'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cors',),
#  ('java',),
#  (),
#  (),
#  ('python',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c++',),
#  ('ios',),
#  (),
#  (),
#  (),
#  ('java',),
#  (),
#  ('html',),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  (),
#  ('ios',),
#  (),
#  ('ruby',),
#  (),
#  (),
#  (),
#  ('ios', 'iphone', 'objective-c'),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  ('javascript', 'reactjs'),
#  ('c#',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('arrays',),
#  (),
#  (),
#  (),
#  ('ios',),
#  (),
#  ('c++',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android', 'gradle'),
#  (),
#  ('ruby',),
#  (),
#  (),
#  ('python',),
#  ('php',),
#  (),
#  (),
#  (),
#  ('sql',),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('ios', 'objective-c'),
#  (),
#  ('ios', 'objective-c', 'uitableview'),
#  ('ios',),
#  (),
#  (),
#  (),
#  (),
#  ('algorithm',),
#  (),
#  (),
#  (),
#  ('python',),
#  ('python',),
#  ('android',),
#  (),
#  (),
#  (),
#  ('python',),
#  ('css', 'html', 'javascript', 'jquery'),
#  (),
#  (),
#  (),
#  ('php',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('ios', 'xcode'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('html',),
#  (),
#  ('css', 'twitter-bootstrap'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript', 'jquery'),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  ('sql',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c++',),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  ('javascript', 'twitter-bootstrap'),
#  (),
#  ('android',),
#  (),
#  (),
#  ('java',),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('c++',),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  ('java',),
#  (),
#  ('ios',),
#  (),
#  (),
#  (),
#  (),
#  ('c++',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('python', 'selenium', 'selenium-webdriver'),
#  ('php',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('android', 'gradle'),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('python',),
#  (),
#  ...]

# %%
joblib.dump(yw2v_pred_rf, open("../Variables/yw2v_pred_rf.joblib", 'wb'), compress=True)
joblib.dump(score_w2v_rf, open("../Scores/score_w2v_rf.joblib", 'wb'), compress=True)
joblib.dump(model_w2v_lr, open("../Models/model_w2v_rf.joblib", 'wb'), compress=True)

# %% [markdown]
# ## USE

# %% [markdown]
# ### Logistic regression

# %%
log_reg_model = OneVsRestClassifier(estimator=LogisticRegression(penalty='l1',
                                                                 solver='saga',
                                                                 C=100,
                                                                 n_jobs=-1), 
                                    n_jobs=-1)

# %%
yuse_pred_lr, score_use_lr, model_use_lr, time_use_lr = modeltrainer(
    X_train_use, X_test_use, y_train, y_test, log_reg_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=LogisticRegression(C=100, n_jobs=-1, penalty='l1',
#                                                  solver='saga'),
#                     n_jobs=-1)
# Temps d'entrainement : 3225.77s
# Evaluation du modele ...
# Temps d'evaluation : 1.70s

# %%
multilabel.inverse_transform(yuse_pred_lr)
# Out:
# [('ios',),
#  ('c++', 'java', 'null'),
#  ('c#', 'excel'),
#  ('dataframe', 'pandas', 'python', 'scala'),
#  ('angular', 'https', 'javascript'),
#  ('c#', 'data-binding', 'wpf', 'xaml'),
#  ('firefox', 'http'),
#  ('asp.net', 'c#', 'pdf', 'security', 'ssl'),
#  (),
#  ('.net', 'c#', 'collections', 'dictionary'),
#  ('java',),
#  ('version-control',),
#  ('python',),
#  ('asp.net',),
#  ('animation', 'ios'),
#  ('dom', 'html', 'javascript', 'jquery'),
#  ('encryption', 'mysql', 'php'),
#  ('functional-programming',),
#  ('ajax', 'asynchronous', 'javascript', 'jquery'),
#  ('machine-learning', 'python'),
#  (),
#  ('c', 'c++', 'pointers', 'string'),
#  (),
#  ('asp.net-mvc',),
#  ('java', 'oracle'),
#  ('android', 'android-layout'),
#  ('arrays', 'java'),
#  ('javascript', 'jquery'),
#  ('debugging',),
#  ('ruby-on-rails', 'testing'),
#  ('swift', 'unit-testing'),
#  ('function',),
#  (),
#  ('android',),
#  ('asp.net-core', 'exception'),
#  (),
#  ('android', 'java'),
#  ('java', 'spring', 'spring-boot', 'spring-mvc'),
#  ('ios', 'xcode'),
#  ('json',),
#  ('architecture', 'java', 'rest'),
#  ('.net', 'c#'),
#  ('authentication', 'cookies', 'php', 'security'),
#  ('sql', 'sql-server'),
#  ('java', 'java-8', 'jvm'),
#  ('database', 'postgresql', 'sql', 'sql-server'),
#  ('javascript',),
#  ('python',),
#  ('postgresql',),
#  ('regex', 'url'),
#  ('java', 'jdbc', 'sql'),
#  ('c++',),
#  ('csv', 'python'),
#  ('ipad', 'iphone'),
#  (),
#  ('arrays', 'javascript', 'regex'),
#  ('javascript',),
#  (),
#  ('eclipse',),
#  ('ios', 'swift', 'xcode'),
#  ('c++',),
#  ('c++', 'performance', 'stl', 'vector'),
#  ('android', 'junit', 'unit-testing'),
#  ('ios', 'xcode'),
#  ('jquery',),
#  ('docker', 'gradle', 'shell'),
#  ('c',),
#  ('qt', 'xcode'),
#  ('asp.net', 'visual-studio', 'visual-studio-2010', 'wcf'),
#  ('asp.net', 'html', 'javascript', 'razor'),
#  ('c#',),
#  ('amazon-s3', 'amazon-web-services', 'javascript', 'node.js'),
#  ('.net', 'c#'),
#  ('javascript',),
#  ('.net', 'c#'),
#  ('sql',),
#  ('linux',),
#  ('eclipse',),
#  ('indexing', 'postgresql'),
#  ('cocoa', 'cocoa-touch', 'ios', 'iphone', 'objective-c'),
#  (),
#  ('java', 'multithreading'),
#  ('mysql', 'php'),
#  ('cocoa', 'sorting'),
#  ('java', 'sockets'),
#  ('floating-point', 'java'),
#  (),
#  (),
#  ('asp.net', 'javascript', 'validation'),
#  ('java',),
#  ('ios', 'iphone', 'objective-c'),
#  (),
#  ('ios',),
#  ('pip', 'python', 'ubuntu'),
#  ('oracle', 'sql-server'),
#  ('python',),
#  ('android',),
#  ('python',),
#  ('amazon-web-services', 'https', 'ssl'),
#  ('security', 'visual-studio-2012'),
#  (),
#  ('java', 'sockets'),
#  ('database', 'php', 'sql'),
#  ('dataframe', 'list', 'python'),
#  ('c++', 'floating-point', 'optimization'),
#  ('version-control',),
#  ('algorithm', 'c++', 'stl'),
#  ('javascript',),
#  ('macos',),
#  ('iphone',),
#  ('linux',),
#  (),
#  ('arrays', 'mongodb', 'object'),
#  ('html', 'javascript', 'jquery'),
#  ('java',),
#  ('ssl',),
#  ('.net', 'c#'),
#  ('java',),
#  ('ios', 'objective-c'),
#  ('email',),
#  ('image-processing', 'python'),
#  ('c++', 'linux'),
#  ('javascript',),
#  ('c#',),
#  ('java', 'web-services'),
#  ('html', 'javascript', 'jquery', 'scroll'),
#  ('docker', 'linux'),
#  ('cocoa', 'xcode'),
#  ('date', 'sql', 'sql-server', 'sql-server-2008', 'tsql'),
#  ('.net', 'c#', 'wpf', 'xaml'),
#  ('.net', 'c#', 'wpf'),
#  ('javascript', 'reactjs', 'vue.js'),
#  ('css', 'google-chrome', 'selenium'),
#  (),
#  ('java',),
#  ('css', 'html'),
#  ('c++', 'pointers'),
#  (),
#  ('c++', 'c++11', 'templates'),
#  ('ios',),
#  (),
#  ('python',),
#  ('css',),
#  ('matplotlib', 'python'),
#  ('text',),
#  ('multithreading',),
#  ('json', 'parsing', 'regex', 'url'),
#  ('build', 'gcc'),
#  (),
#  ('android', 'android-fragments'),
#  ('html', 'ios', 'ipad', 'iphone', 'javascript', 'jquery'),
#  ('android',),
#  ('html',),
#  (),
#  ('django', 'python'),
#  ('java', 'scala', 'types'),
#  ('java', 'swing', 'user-interface'),
#  ('android',),
#  ('concurrency', 'multithreading'),
#  ('python',),
#  ('apache', 'mysql', 'php'),
#  ('asp.net',
#   'asp.net-mvc',
#   'asp.net-mvc-3',
#   'asp.net-mvc-4',
#   'razor',
#   'visual-studio-2010'),
#  ('javascript', 'vue.js'),
#  ('eclipse', 'java'),
#  ('cocoa', 'ios', 'iphone', 'multithreading', 'objective-c', 'uikit'),
#  ('numpy', 'python', 'string'),
#  ('ajax', 'html', 'javascript', 'jquery'),
#  ('android', 'firebase'),
#  ('c#', 'shell', 'unix'),
#  ('android', 'android-gradle-plugin', 'android-studio'),
#  (),
#  ('c#', 'wpf'),
#  ('android', 'eclipse'),
#  ('dart', 'flutter'),
#  ('asp.net', 'html', 'javascript'),
#  ('c++', 'c++11'),
#  ('ios', 'objective-c'),
#  ('css', 'javascript'),
#  ('python', 'selenium'),
#  ('c#', 'visual-studio'),
#  ('python',),
#  ('unit-testing',),
#  ('swift',),
#  ('node.js', 'npm'),
#  ('c#', 'types'),
#  ('apache-spark', 'python', 'python-3.x'),
#  ('sql', 'sql-server', 'sql-server-2008'),
#  ('.net', 'c#', 'wpf'),
#  ('excel',),
#  (),
#  (),
#  ('c#', 'wpf'),
#  ('linux',),
#  ('iphone', 'objective-c'),
#  ('shell', 'unix'),
#  ('scala',),
#  ('c++', 'c++11'),
#  ('c++',),
#  ('dataframe', 'numpy', 'pandas'),
#  ('google-chrome', 'html', 'javascript', 'jquery'),
#  ('asp.net-mvc-4', 'c#', 'entity-framework'),
#  ('bash',),
#  (),
#  ('assembly', 'c++', 'math', 'optimization'),
#  (),
#  (),
#  ('object',),
#  ('html', 'javascript', 'jquery', 'twitter-bootstrap'),
#  ('uiview',),
#  ('api', 'curl', 'php', 'rest'),
#  ('gcc', 'linux'),
#  ('python',),
#  ('batch-file', 'windows'),
#  ('java', 'spring', 'spring-boot', 'spring-mvc', 'tomcat'),
#  ('html', 'twitter-bootstrap'),
#  ('hibernate', 'java', 'logging'),
#  ('html', 'parsing'),
#  ('java',),
#  ('git',),
#  ('javascript', 'jquery'),
#  ('image', 'linux'),
#  ('python',),
#  ('android',),
#  ('c', 'multithreading'),
#  (),
#  (),
#  ('lambda',),
#  ('entity-framework', 'lambda', 'sql'),
#  ('css', 'javascript', 'jquery', 'twitter-bootstrap'),
#  ('java',),
#  ('python',),
#  ('c#', 'generics', 'inheritance'),
#  (),
#  ('java',),
#  ('.net', 'c#', 'entity-framework'),
#  ('machine-learning', 'python', 'tensorflow'),
#  ('postgresql',),
#  ('dataframe',),
#  ('ios', 'iphone', 'objective-c'),
#  ('c#', 'wpf'),
#  (),
#  ('arrays', 'javascript'),
#  ('reactjs', 'rest'),
#  (),
#  ('asp.net-mvc',),
#  ('pandas', 'python', 'sorting'),
#  ('cocoa', 'unix'),
#  ('node.js', 'npm'),
#  ('ajax', 'cors', 'javascript', 'jquery', 'json'),
#  ('angular',),
#  (),
#  ('class', 'java', 'object', 'static'),
#  ('browser',),
#  ('mongodb',),
#  ('c++', 'inheritance'),
#  ('css',),
#  ('css', 'macos'),
#  ('ios', 'ipad', 'iphone'),
#  ('sql', 'sql-server', 'sql-server-2008', 'tsql'),
#  ('pip', 'python', 'python-2.7'),
#  ('dictionary',),
#  ('android',),
#  (),
#  ('c', 'c++'),
#  ('php', 'session', 'static'),
#  ('intellij-idea', 'macos'),
#  ('apache-spark', 'java', 'scala'),
#  ('c++', 'machine-learning'),
#  ('architecture',),
#  ('jquery', 'jquery-ui'),
#  ('excel', 'syntax'),
#  ('algorithm', 'data-structures', 'search'),
#  ('hibernate', 'mysql', 'sql', 'sql-server'),
#  ('python', 'selenium', 'selenium-webdriver'),
#  ('c#', 'rest'),
#  ('arrays', 'csv', 'javascript'),
#  ('css', 'html'),
#  ('class', 'java', 'oop', 'static', 'variables'),
#  ('dom', 'html', 'javascript'),
#  ('java', 'json', 'rest', 'web-services'),
#  ('css', 'html', 'javascript', 'typescript'),
#  ('api', 'php', 'rest'),
#  ('hibernate', 'java', 'spring', 'spring-boot'),
#  ('cocoa', 'cocoa-touch', 'ios', 'objective-c'),
#  ('php',),
#  ('python',),
#  ('security',),
#  (),
#  ('java',),
#  ('android', 'android-studio', 'url'),
#  ('sql', 'sql-server', 'tsql'),
#  ('date',),
#  (),
#  ('hibernate', 'java', 'spring', 'spring-mvc'),
#  (),
#  ('apache-spark', 'dataframe', 'pandas', 'python', 'r'),
#  ('collections', 'java'),
#  ('c#', 'entity-framework'),
#  (),
#  ('c#', 'json'),
#  ('c++',),
#  ('windows',),
#  (),
#  ('macos', 'ruby'),
#  ('facebook',),
#  ('google-maps', 'javascript'),
#  ('javascript', 'node.js', 'sockets'),
#  ('visual-studio', 'visual-studio-2010', 'visual-studio-2012'),
#  ('c++',),
#  ('ios', 'uitableview', 'uiviewcontroller'),
#  ('arrays', 'numpy', 'python'),
#  ('ios', 'xcode'),
#  ('cookies', 'post', 'rest'),
#  ('scripting',),
#  ('java', 'selenium', 'selenium-webdriver'),
#  ('bash', 'terminal', 'ubuntu', 'windows'),
#  (),
#  ('google-chrome',),
#  ('javascript',),
#  ('android',),
#  ('css', 'javascript'),
#  ('c++',),
#  ('android', 'android-layout', 'xml'),
#  ('javascript', 'jquery', 'list'),
#  ('session',),
#  ('cocoa', 'cocoa-touch', 'iphone', 'objective-c', 'sorting'),
#  ('ruby', 'swift'),
#  ('git', 'ssh'),
#  ('python',),
#  ('javascript',),
#  ('.net', 'c#', 'winforms', 'wpf'),
#  ('oop',),
#  ('ipad', 'objective-c'),
#  ('android', 'build', 'gradle'),
#  ('html', 'javascript'),
#  ('ajax', 'javascript', 'jquery', 'json', 'php', 'post'),
#  ('java',),
#  ('asp.net', 'iis'),
#  ('eclipse', 'jakarta-ee', 'java', 'maven'),
#  (),
#  ('http', 'python'),
#  ('json', 'php'),
#  ('maven',),
#  ('ios', 'objective-c'),
#  ('ios', 'swift', 'uitableview'),
#  ('android', 'java'),
#  ('git',),
#  ('apache', 'django', 'python'),
#  ('ios', 'objective-c'),
#  ('java', 'jdbc', 'jpa'),
#  ('java', 'json'),
#  ('facebook',),
#  ('python', 'scipy'),
#  ('php',),
#  ('google-maps', 'r'),
#  ('database', 'sql', 'sql-server', 'tsql'),
#  ('java',),
#  ('c++',),
#  ('c#',),
#  ('html', 'ios', 'ipad', 'iphone'),
#  ('java', 'spring'),
#  ('java',),
#  ('dictionary', 'list', 'python', 'recursion'),
#  ('ios', 'iphone', 'objective-c'),
#  ('nan',),
#  (),
#  ('image', 'python'),
#  ('css', 'html'),
#  ('linq',),
#  ('asp.net', 'c#'),
#  ('machine-learning', 'math'),
#  ('c++', 'floating-point'),
#  ('bash',),
#  ('file', 'file-io', 'java'),
#  ('sql', 'sql-server', 'sql-server-2005'),
#  ('asynchronous', 'cocoa-touch', 'objective-c', 'uitableview'),
#  ('javascript', 'regex'),
#  ('html',),
#  ('android', 'android-studio', 'gradle', 'intellij-idea', 'java'),
#  ('ajax', 'jquery', 'json', 'php', 'xml'),
#  (),
#  ('concurrency', 'python'),
#  ('internet-explorer',),
#  (),
#  ('android', 'android-layout', 'java'),
#  ('hibernate', 'java', 'jpa'),
#  ('language-agnostic', 'oop', 'security'),
#  ('javascript',),
#  ('path', 'python'),
#  ('linux', 'regex'),
#  ('concurrency', 'java', 'oracle'),
#  ('selenium',),
#  ('docker', 'tensorflow'),
#  ('mysql', 'php', 'sql'),
#  ('python', 'python-3.x', 'ruby-on-rails'),
#  ('android', 'arrays', 'data-structures', 'java'),
#  (),
#  (),
#  ('c', 'linux'),
#  ('android', 'google-maps'),
#  ('android',),
#  ('functional-programming',),
#  (),
#  ('git',),
#  (),
#  (),
#  ('android', 'gradle'),
#  ('django', 'json', 'python', 'unicode'),
#  ('hibernate', 'jpa', 'spring'),
#  ('android', 'android-studio', 'firebase'),
#  ('php', 'razor'),
#  (),
#  ('java', 'networking'),
#  ('apache', 'url'),
#  (),
#  ('database',),
#  ('php',),
#  ('nan',),
#  ('.net',),
#  ('cocoa-touch', 'ios', 'objective-c', 'uikit', 'uitableview'),
#  ('java', 'object'),
#  ('c#', 'entity-framework'),
#  ('css', 'ruby-on-rails', 'ruby-on-rails-3', 'twitter-bootstrap'),
#  ('json',),
#  ('ios',),
#  (),
#  ('database', 'oracle', 'sql', 'sql-server'),
#  ('laravel', 'laravel-5', 'php'),
#  ('mvvm',),
#  ('ios', 'ios7', 'objective-c', 'xcode'),
#  (),
#  ('django', 'pandas', 'python'),
#  ('encryption',),
#  ('file-upload', 'iphone', 'web-applications'),
#  ('user-interface',),
#  (),
#  ('ajax', 'jquery', 'php', 'security'),
#  ('dependency-injection',),
#  ('performance', 'python'),
#  ('android',),
#  ('database', 'sql-server', 'sql-server-2008'),
#  ('algorithm', 'c++'),
#  ('java', 'spring', 'spring-boot', 'spring-mvc'),
#  ('data-structures', 'java', 'string'),
#  ('android', 'android-fragments', 'android-layout'),
#  ('bash', 'linux', 'unix'),
#  ('file-io', 'python', 'python-3.x'),
#  ('c', 'gcc', 'recursion'),
#  (),
#  (),
#  ('browser', 'javascript'),
#  ('sql', 'tsql'),
#  ('function', 'opencv'),
#  ('numpy', 'python'),
#  ('.net', 'c#'),
#  ('cocoa', 'ios', 'ipad', 'iphone', 'objective-c', 'swift'),
#  ('css', 'html'),
#  ('image', 'image-processing', 'php'),
#  ('asp.net-mvc', 'c#', 'validation'),
#  ('java', 'web-services'),
#  ('asp.net-core', 'c#'),
#  ('html', 'javascript'),
#  ('collections', 'java', 'list'),
#  ('object',),
#  ('data-binding', 'wpf', 'xaml', 'xml'),
#  ('python',),
#  ('cocoa', 'objective-c'),
#  ('javascript', 'jquery'),
#  ('c#',),
#  ('android',),
#  (),
#  (),
#  ('datetime', 'django', 'pandas', 'python'),
#  ('python',),
#  ('amazon-web-services',),
#  ('dom', 'events', 'javascript', 'jquery'),
#  (),
#  ('assembly', 'performance'),
#  ('ios', 'iphone', 'objective-c'),
#  ('angular', 'mocking', 'testing', 'unit-testing'),
#  ('.net', 'c#', 'file'),
#  ('html', 'selenium-webdriver'),
#  ('php',),
#  ('heroku', 'ruby', 'ruby-on-rails'),
#  ('ios', 'iphone'),
#  ('lambda',),
#  ('javascript',),
#  ('python-3.x',),
#  ('oracle', 'ubuntu'),
#  ('asp.net', 'asp.net-core', 'c#', 'dependency-injection'),
#  (),
#  (),
#  ('linux', 'ruby-on-rails', 'shell', 'terminal', 'ubuntu'),
#  ('android', 'firebase'),
#  ('c#', 'generics', 'inheritance'),
#  ('c#', 'entity-framework', 'interface'),
#  ('php',),
#  ('android', 'video'),
#  ('linux', 'regex'),
#  ('java', 'multithreading'),
#  ('c++', 'windows', 'winforms'),
#  ('apache-spark',),
#  ('debugging', 'exception', 'java', 'java-8'),
#  ('bash', 'linux', 'logging', 'shell', 'unix'),
#  ('ruby-on-rails',),
#  ('c#',),
#  ('ios',),
#  ('animation', 'css', 'html', 'javascript', 'jquery'),
#  ('email', 'php'),
#  ('authentication', 'c#'),
#  ('json', 'web-services'),
#  ('dom', 'html', 'javascript', 'jquery'),
#  (),
#  ('angular', 'javascript'),
#  ('arrays', 'javascript', 'json', 'variables'),
#  ('functional-programming', 'java', 'javascript'),
#  ('.net', 'c#', 'iis'),
#  ('mongodb', 'ruby-on-rails', 'testing'),
#  ('database', 'java', 'spring'),
#  ('macos', 'python'),
#  ('apache', 'php'),
#  (),
#  (),
#  ('python',),
#  ('xcode',),
#  ('google-chrome', 'internet-explorer', 'javascript'),
#  (),
#  ('logging',),
#  ('ios', 'macos'),
#  ('eclipse', 'python'),
#  ('javascript', 'jquery'),
#  ('architecture', 'java', 'spring-mvc'),
#  ('postgresql', 'sql'),
#  ('ios', 'objective-c'),
#  ('asp.net-web-api', 'rest'),
#  ('c#',),
#  ('android', 'build', 'git', 'gradle'),
#  ('nan',),
#  ('django', 'python', 'templates'),
#  (),
#  ('colors',),
#  ('list', 'python'),
#  (),
#  ('class', 'oop', 'scala'),
#  ('android',),
#  ('hibernate', 'java', 'jpa', 'orm'),
#  ('.net', 'c#', 'version-control'),
#  ('c', 'c++', 'memory-management', 'null', 'pointers'),
#  ('image-processing', 'php'),
#  ('date', 'datetime'),
#  ('linux',),
#  ('arrays', 'numpy', 'performance', 'scipy'),
#  ('java', 'rest', 'spring', 'spring-mvc'),
#  (),
#  (),
#  ('c', 'file', 'shell'),
#  ('batch-file', 'windows'),
#  ('jpa', 'sql'),
#  ('machine-learning', 'numpy', 'python', 'scipy'),
#  ('c++', 'class'),
#  ('java',),
#  ('java',),
#  ('authentication', 'php'),
#  ('java', 'multithreading'),
#  ('.net', 'c#'),
#  ('css', 'twitter-bootstrap'),
#  ('html', 'javascript'),
#  ('python',),
#  ('architecture', 'asp.net', 'c#'),
#  (),
#  ('docker',),
#  ('java', 'jdbc'),
#  ('c#', 'performance'),
#  ('collections',),
#  ('html',),
#  ('winapi', 'winforms'),
#  ('ios', 'objective-c'),
#  ('arrays', 'html', 'image'),
#  ('java',),
#  ('android', 'android-gradle-plugin', 'android-studio'),
#  (),
#  (),
#  ('python',),
#  (),
#  ('.net', 'c#'),
#  (),
#  ('database', 'mysql'),
#  ('java', 'maven'),
#  ('authentication', 'encryption', 'php', 'security'),
#  ('algorithm', 'language-agnostic', 'math'),
#  ('javascript', 'jquery'),
#  (),
#  ('architecture',),
#  ('java', 'string'),
#  ('deployment',),
#  ('firebase',),
#  ('ruby', 'ruby-on-rails', 'testing'),
#  ('android', 'networking'),
#  (),
#  ('java',),
#  ('c#', 'linq', 'performance', 'sql', 'sql-server'),
#  ('css', 'javascript'),
#  ('apache-spark', 'dataframe', 'scala'),
#  ('.net', 'c#'),
#  ('macos',),
#  ('.net', 'visual-studio', 'visual-studio-2012'),
#  ('dataframe', 'list', 'python'),
#  ('arrays', 'loops', 'memory'),
#  ('ios', 'macos'),
#  ('mysql', 'sql', 'syntax'),
#  ('asp.net-mvc', 'asp.net-mvc-3', 'asp.net-mvc-4', 'c#', 'razor'),
#  (),
#  ('c#',),
#  ('algorithm', 'data-structures'),
#  ('c#',),
#  ('sql', 'tsql'),
#  ('asp.net-mvc', 'c#', 'linq'),
#  (),
#  ('machine-learning', 'python'),
#  ('deployment', 'git', 'github', 'heroku'),
#  ('async-await', 'asynchronous'),
#  ('sockets',),
#  ('google-maps',),
#  ('http', 'java', 'spring', 'spring-boot'),
#  (),
#  ('html',),
#  ('class', 'inheritance'),
#  ('asp.net-mvc-4', 'jquery'),
#  ('configuration', 'visual-studio', 'visual-studio-2010'),
#  ('android', 'java', 'scala'),
#  ('multithreading',),
#  ('reactjs', 'unit-testing'),
#  ('dataframe', 'pandas', 'python', 'python-2.7'),
#  ('python', 'python-2.7'),
#  ('cocoa', 'ios', 'macos', 'swift', 'xcode'),
#  ('css',),
#  ('android',),
#  ('git', 'javascript', 'node.js', 'npm'),
#  ('pip', 'python', 'python-2.7'),
#  ('functional-programming', 'typescript'),
#  ('curl', 'http', 'php'),
#  ('c#', 'wpf', 'xaml'),
#  ('.net', 'asp.net', 'c#', 'validation', 'winforms'),
#  ('c#',),
#  ('django', 'webpack'),
#  ('memory', 'memory-management'),
#  ('c++', 'visual-c++'),
#  ('ios', 'iphone', 'objective-c', 'uitableview'),
#  ('django', 'logging', 'python'),
#  (),
#  ('html', 'video'),
#  ('ios', 'objective-c'),
#  ('android',),
#  ('haskell',),
#  ('express', 'javascript', 'mongodb', 'node.js', 'rest'),
#  ('concurrency', 'java'),
#  ('data-structures', 'dictionary', 'functional-programming', 'python'),
#  ('node.js',),
#  (),
#  ('android',),
#  ('laravel', 'laravel-5', 'node.js'),
#  ('google-maps',),
#  ('ios', 'xcode'),
#  ('reactjs',),
#  ('javascript', 'jquery'),
#  (),
#  ('functional-programming', 'haskell'),
#  ('.net', 'c#', 'c++11', 'visual-studio'),
#  ('.net', 'c#'),
#  (),
#  (),
#  ('css', 'html', 'twitter-bootstrap'),
#  ('c', 'gcc', 'linux'),
#  ('laravel', 'php'),
#  ('asp.net-mvc', 'entity-framework'),
#  ('pip', 'python', 'ubuntu'),
#  (),
#  ('function', 'sql', 'sql-server'),
#  ('xml',),
#  ('assembly', 'c', 'multithreading', 'x86'),
#  ('r',),
#  ('numpy', 'pandas', 'python', 'video'),
#  ('gcc',),
#  ('ajax', 'cors', 'google-chrome', 'javascript', 'rest'),
#  ('java', 'json', 'rest', 'spring-mvc'),
#  ('ios', 'objective-c', 'uiview'),
#  ('python', 'qt', 'user-interface'),
#  ('python', 'python-2.7'),
#  ('python',),
#  ('windows',),
#  ('python',),
#  ('ios',),
#  ('image', 'opencv'),
#  ('bash', 'node.js', 'npm'),
#  ('java', 'json'),
#  ('java', 'security'),
#  ('javascript', 'reactjs'),
#  ('ajax', 'javascript', 'jquery'),
#  ('javascript', 'node.js'),
#  ('.net', 'c#', 'winforms'),
#  ('angular',),
#  ('swift', 'xcode'),
#  ('exception', 'java'),
#  ('c#', 'console'),
#  ('ajax', 'javascript', 'jquery'),
#  ('c++',),
#  ('ios', 'macos'),
#  ('ajax',
#   'asp.net-mvc',
#   'asp.net-mvc-3',
#   'javascript',
#   'jquery',
#   'validation'),
#  ('git', 'github'),
#  ('c++',),
#  ('.net', 'c#'),
#  (),
#  ('github', 'jenkins'),
#  ('ios', 'uitableview'),
#  ('image-processing', 'machine-learning', 'tensorflow'),
#  ('numpy', 'python'),
#  ('database', 'sql', 'sql-server', 'sql-server-2008', 'tsql'),
#  ('mysql', 'php'),
#  ('javascript', 'unicode'),
#  ('wpf',),
#  ('sql',),
#  ('deployment', 'java', 'web-applications'),
#  ('function',),
#  ('css', 'java'),
#  ('c', 'c++'),
#  ('ios', 'iphone', 'objective-c'),
#  ('android', 'animation'),
#  ('python',),
#  ('algorithm', 'c++', 'stl'),
#  ('java', 'maven'),
#  ('asp.net-mvc', 'asp.net-mvc-4'),
#  ('forms', 'html', 'javascript'),
#  ('windows',),
#  ('rest',),
#  ('colors', 'ios', 'objective-c'),
#  ('ios', 'iphone', 'xcode'),
#  ('ios',),
#  ('configuration', 'eclipse', 'file', 'java'),
#  ('arrays', 'c', 'c++'),
#  ('.net', 'c#'),
#  ('entity-framework',),
#  ('android', 'android-layout', 'user-interface'),
#  (),
#  ('windows',),
#  ('arrays', 'javascript'),
#  ('ios', 'iphone', 'xcode'),
#  ('android', 'android-layout', 'numpy'),
#  ('php',),
#  ('function',),
#  ('ios',),
#  ('android', 'android-studio', 'colors', 'logging'),
#  ('git',),
#  ('c', 'c++'),
#  ('asp.net-mvc', 'c#', 'iis'),
#  ('.net', 'c#'),
#  ('cocoa-touch', 'ios', 'iphone', 'uiviewcontroller'),
#  (),
#  ('authentication', 'cookies', 'ruby-on-rails'),
#  ('multithreading', 'python', 'user-interface'),
#  ('c++',),
#  ('c',),
#  ('android',),
#  ('image',),
#  ('android', 'user-interface'),
#  ('http', 'rest'),
#  ('javascript', 'reactjs'),
#  ('generics', 'string', 'swift'),
#  (),
#  ('ipad',),
#  ('async-await', 'unit-testing'),
#  ('.net', 'c#', 'testing', 'unit-testing'),
#  ('linux', 'ubuntu'),
#  ('asp.net', 'css'),
#  ('android', 'sqlite'),
#  (),
#  ('c++', 'linux'),
#  ('sql',),
#  ('colors', 'html', 'javascript', 'jquery'),
#  ('oop', 'types'),
#  ('java',),
#  ('c#', 'data-binding', 'wpf', 'xaml'),
#  ('c#', 'collections', 'mvvm', 'wpf'),
#  ('numpy', 'performance', 'python'),
#  (),
#  ('arrays', 'c', 'c++', 'pointers'),
#  ('apache', 'ubuntu'),
#  ('node.js',),
#  ('authentication',),
#  ('ios', 'iphone', 'objective-c'),
#  ('c#',),
#  ('c++', 'syntax'),
#  ('java', 'spring'),
#  ('javascript',),
#  ('ajax', 'c#', 'jquery'),
#  (),
#  ('java', 'spring', 'spring-boot'),
#  ('java', 'logging', 'spring'),
#  ('reactjs',),
#  ('tensorflow',),
#  ('android', 'file', 'java', 'memory-management'),
#  ('date', 'html', 'javascript', 'jquery', 'time'),
#  ('java',),
#  (),
#  ('java', 'multithreading', 'user-interface'),
#  ('bash', 'colors'),
#  ('.net', 'c#', 'winapi'),
#  ('android', 'android-studio', 'facebook'),
#  ('class', 'php'),
#  (),
#  ('data-structures', 'python'),
#  ('ajax', 'javascript', 'jquery', 'json', 'mysql', 'php'),
#  ('command-line', 'python', 'python-3.x'),
#  ('apache', 'php'),
#  ('android', 'android-layout', 'android-studio'),
#  ('android', 'image-processing'),
#  ('concurrency', 'java', 'performance'),
#  ('datetime', 'sql', 'sql-server', 'sql-server-2008', 'tsql'),
#  ('http', 'json'),
#  ('html', 'javascript', 'jquery'),
#  ('c#', 'ios'),
#  ('java', 'security'),
#  ('ios', 'uiview', 'uiviewcontroller'),
#  ('javascript', 'reactjs'),
#  ('ios', 'objective-c', 'uitableview'),
#  ('ios', 'iphone'),
#  (),
#  ('android', 'firebase', 'flutter'),
#  ('.net', 'c#', 'wpf'),
#  ('android', 'eclipse'),
#  ('language-agnostic',),
#  ('asp.net',
#   'asp.net-mvc',
#   'asp.net-mvc-4',
#   'asp.net-web-api',
#   'c#',
#   'iis',
#   'url'),
#  ('amazon-web-services',),
#  ('.net', 'c#', 'wpf'),
#  ('python', 'ssl'),
#  ('python',),
#  ('android', 'android-layout'),
#  ('c#', 'wpf'),
#  ('encoding', 'json', 'python', 'unicode'),
#  ('ipad', 'javascript'),
#  ('numpy', 'pip', 'python', 'python-2.7'),
#  ('css', 'html', 'jquery'),
#  ('ruby-on-rails',),
#  (),
#  ('.net', 'windows'),
#  ('laravel', 'php'),
#  ('android',),
#  ('python',),
#  ('animation',),
#  ('excel', 'java'),
#  ('git',),
#  ('c#', 'visual-studio'),
#  ('c#', 'video'),
#  ('xcode',),
#  ('ios', 'ios7', 'swift', 'uiviewcontroller'),
#  ('maven',),
#  ('cors', 'intellij-idea', 'java', 'web-services'),
#  ('android',),
#  ('android',),
#  ('database', 'performance', 'sql', 'sql-server', 'sql-server-2008'),
#  (),
#  ('android', 'eclipse', 'java'),
#  ('ios', 'xcode'),
#  ('express', 'html', 'node.js', 'templates'),
#  (),
#  ('css', 'jquery', 'twitter-bootstrap'),
#  ('html', 'javascript', 'jquery', 'php', 'ruby-on-rails'),
#  ('encoding', 'linux', 'php', 'regex', 'ubuntu'),
#  ('postgresql',),
#  ('docker', 'jenkins', 'linux'),
#  ('encoding', 'file', 'hibernate', 'java', 'utf-8'),
#  ('javascript', 'jquery'),
#  ('debugging',),
#  (),
#  ('ajax', 'javascript'),
#  ('amazon-s3', 'amazon-web-services', 'python'),
#  (),
#  ('javascript',),
#  (),
#  ('javascript', 'mongodb'),
#  ('java', 'rest', 'tomcat'),
#  ('.net', 'c#'),
#  ('.net', 'build'),
#  ('ios', 'swift'),
#  ('android',),
#  ('postgresql',),
#  ('.net-core',),
#  ('firebase', 'node.js'),
#  ('dataframe', 'pandas', 'python', 'text'),
#  ('c#',),
#  ('orm',),
#  ('java', 'jdbc', 'spring', 'tomcat'),
#  ('c++',),
#  ('java', 'maven'),
#  ('java',),
#  ('.net', 'c#', 'vb.net', 'wcf'),
#  ('javascript', 'jquery'),
#  ('java',),
#  ('asp.net', 'session'),
#  ('php',),
#  ('apache', 'performance'),
#  ('c#',),
#  ('installation', 'python', 'windows'),
#  ('xcode',),
#  ('dataframe', 'pandas', 'python'),
#  ('javascript', 'macos', 'node.js', 'npm'),
#  ('android',),
#  ('ios', 'iphone', 'swift'),
#  ('ios', 'uitableview'),
#  ('git',),
#  ('php', 'security'),
#  ('visual-studio',),
#  ('c',),
#  (),
#  (),
#  ('html', 'javascript', 'security'),
#  ('date', 'java', 'java-8', 'json'),
#  ('android',),
#  ('android', 'android-gradle-plugin', 'android-studio', 'gradle'),
#  ('javascript', 'twitter-bootstrap'),
#  ('functional-programming', 'scala'),
#  ('android', 'google-maps'),
#  ('string',),
#  (),
#  ('java', 'list'),
#  ('android', 'gradle', 'unit-testing'),
#  ('android',),
#  ('machine-learning', 'scipy'),
#  (),
#  ('cocoa', 'ios', 'iphone', 'objective-c', 'xcode'),
#  ('iphone', 'objective-c'),
#  ('android', 'android-layout', 'file', 'java'),
#  ('android', 'xml'),
#  ('c', 'c++'),
#  ('java',),
#  ('ios', 'string', 'swift'),
#  ('.net', 'c#'),
#  ('android', 'api'),
#  ('database-design',),
#  ('.net', 'c#'),
#  ('concurrency', 'java'),
#  ('excel', 'pandas'),
#  ('python',),
#  ('android',),
#  ('c++',),
#  ('compiler-construction',),
#  ('cors',),
#  ('java', 'json', 'python'),
#  ('html', 'javascript', 'jquery'),
#  ('express', 'node.js'),
#  ('console', 'javascript'),
#  ('internet-explorer', 'javascript'),
#  ('visual-studio',),
#  ('batch-file', 'windows'),
#  ('c#', 'list', 'sorting'),
#  ('hash', 'javascript'),
#  (),
#  ('jakarta-ee', 'java', 'maven'),
#  ('button',),
#  ('ios', 'objective-c'),
#  ('android', 'android-studio', 'java'),
#  ('java', 'mocking', 'unit-testing'),
#  (),
#  ('cors', 'javascript', 'json', 'python'),
#  ('c++', 'c++11', 'stl'),
#  ('browser', 'pdf'),
#  ('arrays',),
#  ('java', 'rest'),
#  (),
#  ('arrays', 'class', 'static'),
#  ('canvas', 'javascript'),
#  (),
#  ('assembly',),
#  ('colors',),
#  ('c', 'c++', 'recursion'),
#  ('asp.net', 'asp.net-mvc', 'c#'),
#  ('string',),
#  ('javascript', 'reactjs'),
#  ('python', 'r'),
#  ('firefox', 'python', 'selenium'),
#  ('mysql', 'php'),
#  ('haskell',),
#  (),
#  (),
#  (),
#  (),
#  ('.net', 'intellij-idea'),
#  ('bash', 'gcc', 'git'),
#  ('javascript',),
#  ('android', 'gradle'),
#  ('qt',),
#  ('android',),
#  ('ruby', 'ruby-on-rails'),
#  ('c++', 'function'),
#  ('algorithm',),
#  ('amazon-s3', 'amazon-web-services'),
#  ('postgresql', 'ruby', 'ruby-on-rails', 'ruby-on-rails-3'),
#  (),
#  ('collections', 'java'),
#  ('collections', 'python', 'sorting'),
#  (),
#  ...]

# %%
score_use_lr
# Out:
# {'f1_score': 0.5087794599656625,
#  'jaccard_score': 0.3411832430593715,
#  'ROC_Auc_score': 0.71993813794796}

# %%
joblib.dump(yuse_pred_lr, open("../Variables/yuse_pred_lr.joblib", 'wb'), compress=True)
joblib.dump(score_use_lr, open("../Scores/score_use_lr.joblib", 'wb'), compress=True)
joblib.dump(model_use_lr, open("../Models/model_use_lr.joblib", 'wb'), compress=True)

# %% [markdown]
# ### SVC

# %%
svc_model = OneVsRestClassifier(estimator=SVC(), n_jobs=-1)

# %%
yuse_pred_sv, score_use_sv, model_use_sv, time_use_sv = modeltrainer(
    X_train_use, X_test_use, y_train, y_test, svc_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=SVC(), n_jobs=-1)
# Temps d'entrainement : 30221.43s
# Evaluation du modele ...
# Temps d'evaluation : 0.67s

# %%
score_use_sv
# Out:
# {'f1_score': 0.4841233974740148,
#  'jaccard_score': 0.3193686060377832,
#  'ROC_Auc_score': 0.6724140669678402}

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc_model = OneVsRestClassifier(estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1)

# %%
yuse_pred_rf, score_use_rf, model_use_rf, time_use_rf = modeltrainer(
    X_train_use, X_test_use, y_train, y_test, rfc_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1)
# Temps d'entrainement : 4666.82s
# Evaluation du modele ...
# Temps d'evaluation : 1.25s

# %%
score_use_rf
# Out:
# {'f1_score': 0.31215469613259667,
#  'jaccard_score': 0.18494271685761046,
#  'ROC_Auc_score': 0.595760149593853}

# %% [markdown]
# ## BERT

# %% [markdown]
# ### Logistic regression

# %%
log_reg_model = OneVsRestClassifier(estimator=LogisticRegression(n_jobs=-1), n_jobs=-1)

# %%
yber_pred_lr, score_ber_lr, model_ber_lr, time_ber_lr = modeltrainer(
    X_train_bert_hf, X_test_bert_hf, y_train, y_test, log_reg_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=LogisticRegression(n_jobs=-1), n_jobs=-1)
# Temps d'entrainement : 241.05s
# Evaluation du modele ...
# Temps d'evaluation : 0.93s

# %%
score_ber_lr
# Out:
# {'f1_score': 0.40632399722547774,
#  'jaccard_score': 0.25496022812546904,
#  'ROC_Auc_score': 0.6435873991533534}

# %%
multilabel.inverse_transform(yber_pred_lr)
# Out:
# [(),
#  (),
#  ('excel',),
#  ('c#',),
#  (),
#  ('c#', 'mvvm', 'wpf'),
#  (),
#  (),
#  ('css',),
#  (),
#  ('java',),
#  (),
#  ('python',),
#  (),
#  ('animation', 'ios'),
#  ('colors', 'html'),
#  ('mysql',),
#  ('functional-programming',),
#  (),
#  (),
#  (),
#  ('c++', 'pointers'),
#  ('node.js',),
#  ('asp.net-mvc', 'c#'),
#  ('java', 'oracle'),
#  ('android',),
#  ('java',),
#  ('javascript',),
#  (),
#  (),
#  ('unit-testing',),
#  ('function',),
#  (),
#  ('android',),
#  ('.net', 'c#'),
#  ('java', 'pdf'),
#  ('android',),
#  ('spring',),
#  (),
#  (),
#  (),
#  (),
#  ('authentication', 'cookies', 'hash', 'session'),
#  (),
#  ('java', 'jvm'),
#  ('postgresql',),
#  (),
#  ('python',),
#  ('javascript',),
#  ('python', 'url'),
#  ('sql',),
#  (),
#  (),
#  ('ios',),
#  ('visual-studio', 'visual-studio-2010'),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('swift',),
#  (),
#  ('stl',),
#  (),
#  (),
#  (),
#  ('android', 'docker', 'gradle', 'java'),
#  ('c',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  (),
#  (),
#  ('php',),
#  ('postgresql',),
#  ('date', 'jquery', 'sql-server', 'time', 'tsql'),
#  (),
#  (),
#  ('date', 'datetime', 'mysql', 'php'),
#  ('list', 'sorting'),
#  (),
#  ('java', 'performance'),
#  (),
#  (),
#  ('validation',),
#  (),
#  ('ios', 'iphone', 'objective-c'),
#  (),
#  ('ios', 'objective-c'),
#  ('pip', 'python', 'ubuntu'),
#  (),
#  ('colors', 'image'),
#  ('android',),
#  ('matplotlib', 'python'),
#  ('heroku', 'ssl'),
#  (),
#  (),
#  ('java', 'sockets'),
#  (),
#  ('list',),
#  (),
#  (),
#  ('algorithm', 'c++', 'stl', 'vector'),
#  ('javascript',),
#  ('linux',),
#  (),
#  (),
#  ('python',),
#  ('arrays', 'object'),
#  ('jquery',),
#  (),
#  ('ssl',),
#  (),
#  ('eclipse', 'java'),
#  ('ios',),
#  ('email',),
#  ('image', 'image-processing', 'python'),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('dom', 'javascript', 'jquery'),
#  ('docker', 'windows'),
#  ('xcode',),
#  ('datetime', 'sql', 'sql-server', 'sql-server-2008', 'tsql'),
#  (),
#  ('wpf', 'xaml'),
#  ('reactjs',),
#  ('google-chrome', 'selenium', 'selenium-webdriver'),
#  (),
#  ('java', 'templates'),
#  ('css', 'html'),
#  ('c++',),
#  (),
#  ('c++', 'templates'),
#  (),
#  (),
#  (),
#  ('list', 'python', 'selenium', 'selenium-webdriver'),
#  ('macos',),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  (),
#  ('html',),
#  ('android', 'android-fragments'),
#  (),
#  (),
#  ('django', 'java'),
#  (),
#  ('java', 'swing'),
#  ('android', 'android-layout'),
#  ('multithreading',),
#  ('python',),
#  (),
#  (),
#  ('vue.js',),
#  ('c#',),
#  (),
#  ('numpy', 'python'),
#  ('javascript', 'jquery'),
#  ('firebase',),
#  ('file',),
#  ('android', 'java'),
#  (),
#  (),
#  ('android',),
#  ('dart', 'flutter'),
#  ('asp.net',),
#  ('c++',),
#  ('ios', 'objective-c'),
#  ('css',),
#  ('python', 'selenium'),
#  (),
#  ('python',),
#  (),
#  (),
#  ('node.js',),
#  (),
#  ('apache-spark',),
#  (),
#  ('c#',),
#  ('excel',),
#  (),
#  (),
#  ('.net', 'c#', 'visual-studio'),
#  (),
#  ('ios', 'iphone', 'objective-c'),
#  (),
#  ('scala',),
#  (),
#  ('c++',),
#  ('pandas', 'python'),
#  ('css', 'html', 'javascript', 'jquery'),
#  ('.net', 'c#', 'entity-framework'),
#  (),
#  (),
#  ('assembly',),
#  (),
#  ('colors',),
#  (),
#  ('javascript', 'jquery', 'jquery-ui', 'twitter-bootstrap'),
#  ('cocoa-touch', 'ios', 'iphone', 'objective-c', 'uiview', 'uiviewcontroller'),
#  ('api', 'rest'),
#  ('gcc', 'linux', 'ubuntu'),
#  (),
#  ('batch-file', 'windows'),
#  (),
#  ('css', 'html', 'javascript', 'twitter-bootstrap'),
#  ('hibernate', 'java', 'logging'),
#  ('csv', 'html'),
#  ('java',),
#  (),
#  (),
#  (),
#  (),
#  ('android', 'java'),
#  ('c', 'c++', 'performance'),
#  ('css',),
#  ('.net', 'c#'),
#  (),
#  ('c#',),
#  ('javascript',),
#  (),
#  ('python',),
#  (),
#  (),
#  ('java',),
#  ('.net', 'c#', 'entity-framework'),
#  ('tensorflow',),
#  (),
#  (),
#  ('ios', 'iphone'),
#  ('c#', 'mvvm', 'windows', 'wpf', 'xaml'),
#  ('java',),
#  ('google-chrome', 'javascript'),
#  ('api', 'rest'),
#  ('java',),
#  ('javascript',),
#  (),
#  (),
#  ('node.js', 'npm'),
#  ('ajax', 'javascript', 'jquery'),
#  (),
#  (),
#  ('java', 'object'),
#  ('selenium', 'selenium-webdriver'),
#  ('mongodb',),
#  ('c++',),
#  ('css', 'uitableview'),
#  ('css',),
#  (),
#  ('mysql', 'oracle', 'sql', 'sql-server'),
#  ('pip', 'python'),
#  ('dictionary',),
#  ('android',),
#  ('data-structures',),
#  ('c++',),
#  ('session',),
#  (),
#  (),
#  (),
#  ('asp.net-mvc',),
#  ('jquery',),
#  ('time',),
#  ('algorithm', 'data-structures', 'list', 'search'),
#  ('sql',),
#  ('windows',),
#  ('pdf',),
#  ('javascript',),
#  ('css',),
#  ('class', 'java', 'oop'),
#  (),
#  (),
#  (),
#  (),
#  ('java', 'spring', 'spring-boot', 'spring-mvc'),
#  ('cocoa', 'cocoa-touch', 'date', 'javascript'),
#  ('php',),
#  (),
#  (),
#  ('reactjs',),
#  (),
#  (),
#  ('sql',),
#  ('date',),
#  (),
#  (),
#  ('database', 'postgresql'),
#  ('c#',),
#  ('java',),
#  ('c#', 'entity-framework'),
#  (),
#  (),
#  ('algorithm', 'math'),
#  (),
#  (),
#  ('macos',),
#  (),
#  ('google-maps',),
#  ('javascript', 'node.js'),
#  ('c#', 'visual-studio', 'visual-studio-2012'),
#  ('c++',),
#  (),
#  ('arrays', 'numpy', 'python'),
#  (),
#  ('rest', 'web-services'),
#  ('python',),
#  (),
#  ('bash', 'linux'),
#  ('android',),
#  ('google-chrome', 'macos'),
#  ('api', 'javascript'),
#  ('android',),
#  ('javascript',),
#  (),
#  ('android', 'xml'),
#  (),
#  ('cookies', 'javascript'),
#  (),
#  ('search',),
#  ('git', 'windows'),
#  ('python',),
#  ('jquery',),
#  (),
#  ('oop',),
#  ('ios', 'objective-c', 'swift'),
#  ('android', 'java'),
#  ('html', 'javascript'),
#  ('ajax', 'forms', 'html', 'javascript', 'jquery', 'json'),
#  ('java',),
#  (),
#  ('maven',),
#  (),
#  ('python',),
#  (),
#  ('maven',),
#  ('ios', 'objective-c'),
#  ('ios', 'iphone', 'objective-c', 'uitableview'),
#  ('java', 'performance'),
#  ('git',),
#  (),
#  ('ios', 'objective-c', 'swift'),
#  ('java',),
#  ('java',),
#  ('facebook',),
#  ('math',),
#  ('php',),
#  (),
#  ('sql', 'sql-server', 'sql-server-2005', 'sql-server-2008', 'tsql'),
#  (),
#  ('c++', 'optimization', 'x86'),
#  ('c#',),
#  ('ios', 'ipad'),
#  ('hibernate', 'java'),
#  ('java',),
#  ('list',),
#  ('iphone',),
#  (),
#  (),
#  ('matplotlib', 'numpy', 'python', 'scipy'),
#  ('jquery',),
#  ('entity-framework', 'linq'),
#  (),
#  ('boost', 'machine-learning', 'python'),
#  ('assembly', 'c++'),
#  ('node.js',),
#  (),
#  ('sql', 'sql-server', 'tsql'),
#  ('ios', 'objective-c', 'uitableview'),
#  ('javascript',),
#  ('html', 'javascript'),
#  (),
#  ('javascript', 'xml'),
#  (),
#  (),
#  ('browser', 'firefox', 'google-chrome', 'internet-explorer', 'javascript'),
#  (),
#  ('android', 'android-layout'),
#  ('java', 'jpa'),
#  (),
#  ('html',),
#  ('python',),
#  (),
#  (),
#  ('angularjs', 'javascript'),
#  (),
#  ('mysql', 'php', 'sql'),
#  (),
#  ('arrays', 'java', 'list', 'string'),
#  ('android',),
#  (),
#  ('c++',),
#  ('android',),
#  (),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('image',),
#  ('android', 'gradle'),
#  ('django', 'json'),
#  ('java', 'jpa', 'spring', 'spring-boot'),
#  ('android',),
#  ('php',),
#  (),
#  ('java', 'rest'),
#  ('url',),
#  (),
#  ('c#',),
#  (),
#  (),
#  (),
#  ('ios',),
#  ('java', 'object'),
#  ('c#', 'entity-framework', 'linq'),
#  (),
#  (),
#  ('ios',),
#  (),
#  ('oracle', 'types'),
#  ('laravel', 'php'),
#  ('wpf',),
#  ('android', 'ios'),
#  (),
#  ('python',),
#  (),
#  ('iphone',),
#  ('html',),
#  ('image',),
#  ('ajax', 'jquery', 'mysql', 'php'),
#  (),
#  ('python',),
#  (),
#  (),
#  ('algorithm',),
#  ('java', 'spring', 'spring-boot', 'spring-mvc', 'tomcat'),
#  ('java',),
#  ('android',),
#  ('linux', 'unix'),
#  ('python', 'string'),
#  ('c',),
#  (),
#  ('amazon-web-services',),
#  (),
#  ('sql',),
#  ('javascript',),
#  ('numpy', 'python'),
#  ('sockets',),
#  ('ios', 'iphone', 'objective-c'),
#  ('css', 'html', 'input'),
#  ('file-upload', 'php'),
#  ('.net', 'asp.net-mvc', 'c#'),
#  (),
#  (),
#  (),
#  ('c#', 'java', 'list'),
#  ('python',),
#  ('xml',),
#  ('python',),
#  (),
#  ('testing',),
#  (),
#  ('android', 'android-layout', 'uiscrollview'),
#  ('colors',),
#  (),
#  ('django', 'python'),
#  ('machine-learning', 'opencv', 'python'),
#  (),
#  ('events', 'javascript'),
#  (),
#  ('c++', 'loops'),
#  (),
#  ('testing',),
#  ('c#', 'file'),
#  ('selenium', 'selenium-webdriver'),
#  ('xml',),
#  ('path',),
#  ('ios',),
#  (),
#  ('javascript',),
#  ('algorithm', 'list', 'search'),
#  ('eclipse', 'java', 'jdbc', 'oracle'),
#  ('asp.net-web-api',),
#  (),
#  ('c++',),
#  (),
#  (),
#  (),
#  ('c#', 'entity-framework'),
#  ('php',),
#  ('android',),
#  ('linux', 'regex', 'shell'),
#  ('java', 'multithreading'),
#  (),
#  ('apache-spark',),
#  (),
#  ('bash', 'logging', 'shell'),
#  ('css', 'jquery', 'ruby-on-rails', 'twitter-bootstrap'),
#  ('c#', 'html'),
#  (),
#  ('css', 'html', 'javascript', 'jquery'),
#  (),
#  ('c#',),
#  ('json', 'web-services'),
#  ('html', 'javascript', 'jquery'),
#  (),
#  (),
#  ('arrays', 'javascript', 'json'),
#  ('java', 'javascript'),
#  (),
#  ('mongodb', 'testing', 'unit-testing'),
#  ('java', 'spring', 'spring-boot'),
#  ('pip', 'python'),
#  ('php',),
#  (),
#  (),
#  (),
#  (),
#  ('json',),
#  (),
#  ('logging',),
#  ('jenkins',),
#  ('django', 'python'),
#  ('javascript', 'jquery'),
#  ('java', 'rest', 'spring', 'spring-mvc', 'tomcat'),
#  ('postgresql',),
#  (),
#  (),
#  (),
#  ('android', 'gradle', 'java'),
#  (),
#  ('django',),
#  (),
#  (),
#  ('list', 'python'),
#  ('node.js', 'npm', 'vue.js'),
#  (),
#  (),
#  ('hibernate', 'java', 'jpa'),
#  (),
#  ('pointers',),
#  ('php',),
#  (),
#  ('linux', 'shell'),
#  ('numpy', 'python'),
#  ('java', 'spring'),
#  ('file',),
#  (),
#  (),
#  (),
#  ('sql',),
#  ('machine-learning', 'numpy', 'python', 'scipy'),
#  (),
#  ('java',),
#  (),
#  (),
#  ('c#', 'java', 'multithreading'),
#  (),
#  (),
#  (),
#  ('macos', 'python'),
#  (),
#  (),
#  ('docker', 'ubuntu'),
#  ('sql-server',),
#  ('data-structures', 'language-agnostic', 'performance'),
#  (),
#  ('html',),
#  (),
#  ('ios',),
#  ('html',),
#  ('java', 'optimization'),
#  ('android', 'android-gradle-plugin'),
#  (),
#  ('android',),
#  (),
#  (),
#  (),
#  (),
#  ('mysql', 'sql'),
#  ('maven',),
#  ('encryption', 'https', 'security'),
#  ('algorithm', 'python'),
#  ('ajax',),
#  ('ios',),
#  (),
#  ('string',),
#  (),
#  ('firebase',),
#  ('ruby', 'ruby-on-rails', 'testing', 'unit-testing'),
#  (),
#  (),
#  ('java', 'sql'),
#  ('c#', 'performance'),
#  (),
#  ('scala',),
#  ('visual-studio', 'visual-studio-2012'),
#  (),
#  ('visual-studio', 'visual-studio-2010', 'visual-studio-2012'),
#  ('python',),
#  ('arrays',),
#  (),
#  ('mysql', 'php', 'sql', 'sql-server'),
#  (),
#  (),
#  (),
#  ('algorithm', 'java'),
#  (),
#  (),
#  (),
#  ('colors',),
#  ('machine-learning', 'python'),
#  (),
#  ('async-await',),
#  ('sockets',),
#  ('api', 'google-maps'),
#  (),
#  (),
#  (),
#  (),
#  ('asp.net-mvc', 'jquery'),
#  (),
#  ('android',),
#  ('multithreading',),
#  ('reactjs',),
#  ('pandas', 'python'),
#  ('python',),
#  (),
#  (),
#  (),
#  ('npm',),
#  ('installation', 'pip', 'python'),
#  (),
#  ('curl', 'php'),
#  (),
#  (),
#  ('visual-studio', 'visual-studio-2010'),
#  ('django', 'heroku', 'pip', 'python'),
#  (),
#  (),
#  ('ios', 'iphone', 'uitableview'),
#  ('django', 'python'),
#  (),
#  ('video',),
#  ('ios',),
#  ('android', 'android-studio'),
#  (),
#  ('express',),
#  ('ios',),
#  ('python',),
#  (),
#  (),
#  (),
#  ('docker', 'laravel'),
#  (),
#  ('ios', 'xcode'),
#  (),
#  (),
#  ('java',),
#  ('haskell',),
#  ('c++', 'compiler-construction'),
#  ('firebase',),
#  ('bash', 'python'),
#  (),
#  ('css', 'html', 'javascript', 'twitter-bootstrap'),
#  ('linux', 'ubuntu'),
#  ('laravel', 'php'),
#  ('architecture', 'asp.net-mvc', 'c#', 'entity-framework'),
#  ('python',),
#  (),
#  ('sql',),
#  ('java', 'xml'),
#  ('assembly', 'c', 'x86'),
#  (),
#  ('video',),
#  ('c++', 'gcc', 'visual-c++'),
#  ('cors',),
#  ('java', 'json'),
#  (),
#  (),
#  ('python',),
#  (),
#  ('c#',),
#  (),
#  (),
#  (),
#  ('bash', 'command-line', 'shell'),
#  ('json',),
#  ('algorithm', 'java'),
#  ('javascript', 'reactjs'),
#  (),
#  ('node.js',),
#  ('c#',),
#  ('ios',),
#  (),
#  ('exception',),
#  (),
#  ('ajax', 'javascript', 'jquery'),
#  (),
#  ('ios',),
#  (),
#  ('git', 'github'),
#  (),
#  (),
#  (),
#  ('git', 'github', 'jenkins'),
#  (),
#  (),
#  ('numpy', 'python'),
#  ('sql', 'sql-server', 'sql-server-2005', 'tsql'),
#  ('mysql', 'php'),
#  ('javascript',),
#  ('windows', 'wpf'),
#  ('pandas', 'php', 'python', 'sql'),
#  ('java', 'web-applications'),
#  ('c++',),
#  (),
#  (),
#  ('ios', 'iphone'),
#  ('android',),
#  ('multithreading',),
#  (),
#  ('c#', 'java'),
#  ('asp.net', 'asp.net-mvc', 'asp.net-mvc-3', 'c#'),
#  ('android', 'html', 'javascript'),
#  (),
#  ('xml',),
#  (),
#  ('ios',),
#  ('ios', 'iphone', 'objective-c'),
#  ('eclipse', 'java'),
#  ('arrays', 'c', 'c++'),
#  ('c#', 'multithreading'),
#  (),
#  ('android', 'android-layout'),
#  (),
#  ('windows',),
#  ('arrays', 'jquery'),
#  ('ios',),
#  ('android', 'android-layout'),
#  ('php',),
#  ('list',),
#  ('ios',),
#  (),
#  ('ruby', 'ruby-on-rails'),
#  ('c',),
#  (),
#  ('java', 'maven'),
#  ('ios',),
#  ('javascript', 'jquery'),
#  ('cookies',),
#  (),
#  (),
#  ('c',),
#  (),
#  ('css',),
#  ('android',),
#  (),
#  ('reactjs',),
#  (),
#  (),
#  (),
#  ('async-await',),
#  (),
#  ('ubuntu',),
#  ('css',),
#  (),
#  (),
#  ('linux',),
#  ('performance',),
#  ('colors', 'javascript', 'jquery'),
#  ('c#',),
#  ('eclipse', 'java'),
#  ('wpf', 'xaml'),
#  ('wpf',),
#  ('python',),
#  (),
#  ('arrays', 'c++', 'pointers'),
#  (),
#  (),
#  (),
#  ('objective-c',),
#  ('.net', 'c#', 'database', 'performance', 'sql-server'),
#  ('c++',),
#  ('date', 'json'),
#  ('javascript', 'jquery'),
#  ('asp.net', 'jquery', 'json'),
#  (),
#  (),
#  ('c#', 'logging'),
#  ('reactjs',),
#  (),
#  (),
#  ('jquery',),
#  (),
#  ('java',),
#  (),
#  (),
#  (),
#  ('android',),
#  ('arrays', 'function'),
#  ('macos', 'ruby'),
#  ('python',),
#  ('ajax', 'javascript', 'jquery', 'php'),
#  ('python',),
#  ('apache',),
#  ('android',),
#  (),
#  ('java',),
#  ('date', 'datetime', 'sql', 'sql-server', 'tsql'),
#  ('json',),
#  ('javascript',),
#  (),
#  ('authentication', 'java'),
#  ('ios', 'objective-c', 'uiview'),
#  ('javascript', 'reactjs'),
#  ('ios', 'iphone', 'objective-c', 'uitableview'),
#  ('ios',),
#  (),
#  ('firebase',),
#  ('c#',),
#  ('android', 'eclipse'),
#  ('algorithm', 'math'),
#  ('url',),
#  (),
#  (),
#  (),
#  ('python',),
#  ('android',),
#  (),
#  ('python',),
#  ('iphone',),
#  ('pip', 'python'),
#  ('dom', 'html', 'jquery'),
#  ('ruby', 'ruby-on-rails'),
#  (),
#  (),
#  ('laravel', 'php'),
#  (),
#  ('python',),
#  (),
#  ('excel', 'java'),
#  ('git',),
#  (),
#  (),
#  ('ios', 'iphone', 'macos', 'xcode'),
#  ('ios', 'uiviewcontroller'),
#  ('maven',),
#  (),
#  ('android',),
#  ('facebook',),
#  ('database', 'performance', 'sql', 'sql-server'),
#  (),
#  (),
#  (),
#  ('html',),
#  ('string',),
#  ('apache-spark', 'css', 'jquery', 'twitter-bootstrap'),
#  ('html', 'javascript'),
#  ('php', 'ubuntu'),
#  ('postgresql',),
#  ('docker', 'jenkins'),
#  (),
#  ('events', 'javascript', 'jquery'),
#  ('debugging',),
#  (),
#  ('jquery',),
#  ('python',),
#  (),
#  ('javascript',),
#  (),
#  (),
#  ('java',),
#  ('c#',),
#  (),
#  (),
#  (),
#  ('mysql', 'postgresql'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('maven',),
#  (),
#  (),
#  ('java',),
#  (),
#  ('asp.net',),
#  (),
#  ('php',),
#  ('c#', 'entity-framework'),
#  ('python',),
#  ('ios', 'iphone', 'xcode'),
#  ('csv', 'dataframe', 'pandas'),
#  ('macos', 'node.js'),
#  ('windows',),
#  (),
#  ('ios', 'uitableview'),
#  ('git',),
#  ('php',),
#  (),
#  ('c++',),
#  (),
#  ('css', 'html', 'javascript', 'jquery'),
#  ('html', 'javascript', 'jquery'),
#  (),
#  ('android',),
#  ('android', 'android-studio'),
#  ('css', 'html', 'javascript', 'jquery', 'twitter-bootstrap'),
#  ('scala',),
#  ('android', 'google-maps'),
#  ('string',),
#  ('apache', 'authentication'),
#  ('arrays', 'list'),
#  ('unit-testing',),
#  ('android', 'android-layout'),
#  ('scipy',),
#  (),
#  (),
#  ('ios',),
#  ('android',),
#  ('android',),
#  (),
#  (),
#  ('ios', 'swift'),
#  (),
#  ('android', 'api', 'google-maps'),
#  (),
#  (),
#  ('concurrency',),
#  ('excel',),
#  ('python',),
#  (),
#  ('multithreading',),
#  (),
#  ('cors',),
#  ('json',),
#  (),
#  ('express', 'javascript', 'node.js'),
#  ('logging',),
#  ('javascript',),
#  (),
#  ('batch-file', 'windows'),
#  (),
#  ('javascript', 'jquery'),
#  ('python',),
#  ('hibernate', 'java'),
#  ('button', 'javascript', 'jquery'),
#  ('ios',),
#  (),
#  ('mocking', 'unit-testing'),
#  (),
#  ('ajax', 'javascript', 'jquery'),
#  ('c++',),
#  ('pdf',),
#  ('arrays',),
#  (),
#  (),
#  (),
#  ('javascript',),
#  (),
#  ('c#',),
#  (),
#  (),
#  (),
#  (),
#  ('css', 'reactjs'),
#  (),
#  ('firefox', 'selenium', 'selenium-webdriver'),
#  ('mysql', 'php'),
#  (),
#  ('ios',),
#  ('javascript',),
#  (),
#  (),
#  ('visual-studio',),
#  ('bash', 'git'),
#  (),
#  ('gradle',),
#  (),
#  ('android',),
#  (),
#  ('class',),
#  (),
#  ('amazon-web-services',),
#  ('ruby-on-rails', 'ruby-on-rails-3'),
#  (),
#  ('java',),
#  ('algorithm', 'python'),
#  ('algorithm',),
#  ...]

# %%
joblib.dump(yber_pred_lr, open("../Variables/yber_pred_lr.joblib", 'wb'), compress=True)
joblib.dump(score_ber_lr, open("../Scores/score_ber_lr.joblib", 'wb'), compress=True)
joblib.dump(model_ber_lr, open("../Models/model_ber_lr.joblib", 'wb'), compress=True)

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc_model = OneVsRestClassifier(estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1)

# %%
yber_pred_rf, score_ber_rf, model_ber_rf, time_ber_rf = modeltrainer(
    X_train_bert_hf, X_test_bert_hf, y_train, y_test, log_reg_model)
# Out:
# ==========================================================================================
# Modele utilise : OneVsRestClassifier(estimator=LogisticRegression(n_jobs=-1), n_jobs=-1)
# Temps d'entrainement : 250.61s
# Evaluation du modele ...
# Temps d'evaluation : 0.89s

# %%
score_ber_rf
# Out:
# {'f1_score': 0.40632399722547774,
#  'jaccard_score': 0.25496022812546904,
#  'ROC_Auc_score': 0.6435873991533534}

# %%
metrics = ['f1_score', 'jaccard_score', 'ROC_Auc_score']
raw = [["BERT", "TFIDF", "USE", "W2V"]]

# %%
# Create table of scoring
Scores = pd.DataFrame(columns=metrics)
# Affecting socring for each models
for metric in metrics:
    Scores[metric] = [score_ber_lr[metric], score_tfidf_lr[metric],
                      score_use_lr[metric], score_w2v_lr[metric]]
# Set index with corresponding models    
Scores.set_index(raw)
# Out:
#        f1_score  jaccard_score  ROC_Auc_score
# BERT   0.406324       0.254960       0.643587
# TFIDF  0.326511       0.195108       0.609741
# USE    0.508779       0.341183       0.719938
# W2V    0.410459       0.258225       0.650172
